# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.sql.types import *

# %%
display(dbutils.fs.ls("/Volumes/workspace/olist/volume_olist/"))

# %%
## Customer Data Set 

cust_ds = spark.read.csv("/Volumes/workspace/olist/volume_olist/olist_customers_dataset.csv", header= False)
cust_ds.show(5)

# %%
cust_ds.printSchema()
